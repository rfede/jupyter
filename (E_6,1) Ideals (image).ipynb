# %%
# Out:
# ________________________________________
# <p></p><p></p><p></p><p></p><p></p><p></p><h1><center><strong>Ideal: ((0, 1, 0, 0, 0, 0),)</strong></center></h1>
# ________________________________________
# <p></p><p></p><p></p><p></p><p></p><p></p><h1><center><strong>Ideal: ((0, 1, 1, 0, 0, 0),)</strong></center></h1>
# ________________________________________
# <p></p><p></p><p></p><p></p><p></p><p></p><h1><center><strong>Ideal: ((0, 1, 1, 1, 0, 0),)</strong></center></h1>
# ________________________________________
# <p></p><p></p><p></p><p></p><p></p><p></p><h1><center><strong>Ideal: ((0, 1, 1, 1, 1, 0),)</strong></center></h1>
# ________________________________________
# <p></p><p></p><p></p><p></p><p></p><p></p><h1><center><strong>Ideal: ((0, 1, 1, 1, 1, 1),)</strong></center></h1>
# ________________________________________
# <p></p><p></p><p></p><p></p><p></p><p></p><h1><center><strong>Ideal: ((1, 1, 1, 1, 0, 0),)</strong></center></h1>
# ________________________________________
# ...
