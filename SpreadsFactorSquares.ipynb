# %% [markdown]
# ![Spread%20root%20formulas.jpg](attachment:Spread%20root%20formulas.jpg)

# %%
from sympy import *
from IPython.display import display, Markdown, Math
init_session(use_latex=True)
from math import comb
# Out:
# IPython console for SymPy 1.9 (Python 3.9.7-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
def Spread(n):
    s=Symbol('s')
    p=0
    for k in range(1,n+1):
        p += 2 * n * (-4)**(k-1) * binomial(n+k,2*k)/(n+k) * s**k
    return  p



def CompositeSpread(n):
    nfactors = factorint(n)
    p = Symbol('s')
    for b in sorted(nfactors, reverse=True):
        for i in range(nfactors[b]):
            p = p.subs(Symbol('s'),Spread(b))
    return p

n, k, s = symbols('n,k,s')

def SpreadPartialRoots(n):
    k = n//2
    s = Symbol('s')
    p=0
    osw = ((-1)**(n + 1)+1) # switch for odd
    esw = ((-1)**n+1) #  switch for even
    for i in range(k+1):
        p += (-4*s)**i * binomial(k+i,k-i) * \
                ((n* s*(k + i)*osw+i*(2* i+1)*esw)/(2*(2* i + 1)*s*(k + i)) )
    return  s * (1-s)**(((-1)**(n)+1)//2) * p**2

for n in range(2,31):
    spread = Spread(n)
    root = SpreadPartialRoots(n)
    display(
                Markdown(
                    '{}'.format(latex(Indexed('S',n), mode='inline'))+\
                    '= {}'.format(latex(root, mode='inline'))+\
                    ' = {}'.format(latex(spread, mode='inline'))),
                Markdown(
                    '{}'.format(latex('Identity ', mode='inline'))+\
                    '{}'.format(latex(spread.expand()==root.expand(), mode='inline'))),
                Markdown('{}'.format(latex('', mode='inline')))
                    
            )
# Out:
# ${S}_{2}$= $4 s \left(1 - s\right)$ = $- 4 s^{2} + 4 s$
# $\mathtt{\text{Identity }}$$\text{True}$
# $\mathtt{\text{}}$
# ${S}_{3}$= $s \left(3 - 4 s\right)^{2}$ = $16 s^{3} - 24 s^{2} + 9 s$
# $\mathtt{\text{Identity }}$$\text{True}$
# $\mathtt{\text{}}$
# ${S}_{4}$= $s \left(1 - s\right) \left(8 s - 4\right)^{2}$ = $- 64 s^{4} + 128 s^{3} - 80 s^{2} + 16 s$
# $\mathtt{\text{Identity }}$$\text{True}$
# $\mathtt{\text{}}$
# ${S}_{5}$= $s \left(16 s^{2} - 20 s + 5\right)^{2}$ = $256 s^{5} - 640 s^{4} + 560 s^{3} - 200 s^{2} + 25 s$
# $\mathtt{\text{Identity }}$$\text{True}$
# $\mathtt{\text{}}$
# ${S}_{6}$= $s \left(1 - s\right) \left(- 32 s^{2} + 32 s - 6\right)^{2}$ = $- 1024 s^{6} + 3072 s^{5} - 3456 s^{4} + 1792 s^{3} - 420 s^{2} + 36 s$
# $\mathtt{\text{Identity }}$$\text{True}$
# $\mathtt{\text{}}$
# ${S}_{7}$= $s \left(- 64 s^{3} + 112 s^{2} - 56 s + 7\right)^{2}$ = $4096 s^{7} - 14336 s^{6} + 19712 s^{5} - 13440 s^{4} + 4704 s^{3} - 784 s^{2} + 49 s$
# ...
